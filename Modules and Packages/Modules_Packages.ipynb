# %% [markdown]
# # Modules and Packages

# %%
def addition(num1, num2):
    return num1+num2

# %%
addition(4,5)
# Out:
# 9

# %% [markdown]
# ##### I want to use this logic of the function in this file into the other files

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
## How complex the logic of square root function is goint to be

# %% [markdown]
# ## Module
# ##### A module in Python is simply a file containing python code (functions, classes or variables) that can be imported and used in other programs

# %% [markdown]
# ##### Numpy ---> Numpy module is going to help us out with applying scientific calculations on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the list
#
# ##### ---> We can do it in Numpy just becasue Numpy is having the collection of functions and attributes which can help us to work efficiently with the array

# %% [markdown]
# ### Pandas
#
# ##### Pandas we can use when we are going to work with the dataset for cleaning, pre processing, EDA, analysis with plotting as well

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
# A Module:

#1. A Module helps in code organization
#2. It promotes reusablity
#3. It keeps the code clean and manageable as well

print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy

# %%
list_items=[[1,2,3,4,5]]
print(numpy.array(list_items))
# Out:
# [[1 2 3 4 5]]

# %%
list_item=[[1,2,3,4,5]]
numpy_array=numpy.array(list_item)
print(type(numpy_array))
print(numpy_array)
# Out:
# <class 'numpy.ndarray'>
# [[1 2 3 4 5]]

# %%
# !pip install seaborn

# %% [markdown]
# ##### I am trying to create my own or Modue library and in this library I want the funtions and the attributes to be created on my own

# %% [markdown]
# ##### __init__.py is file that has to be their inside the package folder and this __init__.py file help us out in defining our packages and initializing their namespaces as well
#
# ##### This file can remain empty and its completly fine but this file has to there when we will creating our new packages into the packages folder

# %%
from package_folder.mathematics import addition

# %%
addition(4,8)
# Out:
# 12

# %%
from package_folder.mathematics import *
division(10,0)
# Out:
# 'Enter the valid value'

# %%
division(8,2)
# Out:
# 4.0

# %%
from package_folder.subpackage.sum import *
addition(2,3,1)
# Out:
# 6
