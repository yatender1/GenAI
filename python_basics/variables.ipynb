# %% [markdown]
# ## Variables

# %% [markdown]
# ## Variables are the element in python that can be used for storing data into it or values into it or they can be referred as containers as well.
# ## Variables as per its name, data can vary that we are going to store into it once we have declared a variable we can vary the value stored in it.

# %%
age = 23
Name = "Amit"
Height = "5.8"
is_true = True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# '5.8'

# %%
Name
# Out:
# 'Amit'

# %% [markdown]
# ## print() ---> print function is being used to represent the value that we are going to pass inside it

# %%
print("Name is: ", Name)
# Out:
# Name is:  Amit

# %% [markdown]
# ## Variable Naming Convention
