# %% [markdown]
#  # What is Python Language?

# %% [markdown]
# ## Python is a type of programming language which we can use for communicating with computers or technology.

# %% [markdown]
# # Syntax for Python language

# %% [markdown]
# ## Syntax refers to the set of rule that defines the combination of symbols that are considered to be correctly structured programs in a language

# %% [markdown]
# # Semantics of Python language

# %% [markdown]
# ## Semantics of python language refers to the meaning or interpretation of symbols, characters and commands in a language. It is about what the code is suppose to do when it runs.

# %% [markdown]
# # Python Syntax Rules

# %% [markdown]
# ## 1. Python is case sensitive

# %% [markdown]
# # Indentation in Python

# %% [markdown]
# ## In other programming language, we use {} for grouping or statements
# ## In python, we use Indentation for proper grouping of statements as the proper arrangement of statements with proper spacing in the statements within a block.

# %%
age = int(input("Enter your age: "))
if age > 18 :
    print("you are eligible for driving")
# Out:
# you are eligible for driving

# %%
age = int(input("Enter your age: "))
if age > 18 :
print("you are eligible for driving")
# Out:
#   Cell In[1], line 3
#     print("you are eligible for driving")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
1+2+3+4+5
# Out:
# 15

# %% [markdown]
# ## Line Continuation --> we can use backslash for continuing the statement on the next line

# %%
1+2+3+4+5+\
6+7
# Out:
# 28

# %% [markdown]
# ## Multiple Statements in a single line in Python

# %%
a=5; b=6; c=3;
