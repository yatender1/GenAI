# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classification of the data that tells the compiler or the interpreter that what kind of values we can store into a variable and how much amount of memory will be consumed to store the data and the operation it can perform.

# %%
age=input("Enter the age:")

# %%
age
# Out:
# '23'

# %%
print(type(age))
# Out:
# <class 'str'>

# %% [markdown]
# ## Diffrent types of Data Types

# %% [markdown]
# ## 1. int
# ## 2. str
# ## 3. bool
# ## 4. Float
